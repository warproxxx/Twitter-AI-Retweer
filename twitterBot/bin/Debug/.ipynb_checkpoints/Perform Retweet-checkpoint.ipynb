# %%
import pandas as pd

# %%
import tweepy
from tweepy import OAuthHandler

consumer_key = '4xOkrmqdMNh07gpi9dZwBu9Mh'
consumer_secret = 'u2PuEHOuo4XOVSNgzViqAbq4QvpVAVPgXZRFjs1u7CLpjvcx7I'
access_token = '852009551876431872-vLH3HnR07RewycyCHgheMVWKNC26yr4'
access_secret = 't9hfklwg22UWXe7Cpqf1CLj7t1NOgYbWP5VL0HMlSNJHt'

auth = OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)

api = tweepy.API(auth)

# %%
high = pd.read_csv('high.csv', header=None)
high
# Out:
#                      0                    1  \
# 0   981491444056805376  2018-04-04 11:19:30
# 1   981491012639051776  2018-04-04 11:17:47
# 2   981490951247007750  2018-04-04 11:17:32
# 3   981490816890888192  2018-04-04 11:17:00
# 4   981490363734032384  2018-04-04 11:15:12
# 5   981490343576293376  2018-04-04 11:15:07
# 6   981490296616865792  2018-04-04 11:14:56
# 7   981490093805490176  2018-04-04 11:14:08
# 8   981490067310039040  2018-04-04 11:14:01
# 9   981490022393241600  2018-04-04 11:13:51
# 10  981489912577892353  2018-04-04 11:13:25
# 11  981489850711969794  2018-04-04 11:13:10
# 12  981489702334287875  2018-04-04 11:12:34
# 13  981489519961788416  2018-04-04 11:11:51
# 14  981489404953939968  2018-04-04 11:11:23
# 15  981489276461428736  2018-04-04 11:10:53
# 16  981489094260871170  2018-04-04 11:10:09
# 17  981488934373994496  2018-04-04 11:09:31
# 18  981488668690051072  2018-04-04 11:08:28
# 19  981488657470177281  2018-04-04 11:08:25
# ...

# %%
api.update_status(" test tweet", in_reply_to_status_id = high.iloc[3][0])
# Out:
# Status(_api=<tweepy.api.API object at 0x000002659C5130B8>, _json={'created_at': 'Wed Apr 04 08:13:50 +0000 2018', 'id': 981444720294612995, 'id_str': '981444720294612995', 'text': '@ACTORPenelopeD ooo', 'truncated': False, 'entities': {'hashtags': [], 'symbols': [], 'user_mentions': [{'screen_name': 'ACTORPenelopeD', 'name': 'Penny 🎬', 'id': 810481466354171910, 'id_str': '810481466354171910', 'indices': [0, 15]}], 'urls': []}, 'source': '<a href="http://dash.kingmakers.ltd" rel="nofollow">Social Media - Kingmakers</a>', 'in_reply_to_status_id': 952638730069712897, 'in_reply_to_status_id_str': '952638730069712897', 'in_reply_to_user_id': 810481466354171910, 'in_reply_to_user_id_str': '810481466354171910', 'in_reply_to_screen_name': 'ACTORPenelopeD', 'user': {'id': 852009551876431872, 'id_str': '852009551876431872', 'name': 'John Doe', 'screen_name': 'warproxxx', 'location': '', 'description': '', 'url': None, 'entities': {'description': {'urls': []}}, 'protected': False, 'followers_co
# ...

# %%
aa = api.get_status(high.iloc[3][0])

# %%
a = ''

for user in aa._json['entities']['user_mentions']:
    a = '@' + user['screen_name'] + ' '
    
print(a)
# Out:
# @ACTORPenelopeD

# %%
aa._json['entities']['user_mentions']
